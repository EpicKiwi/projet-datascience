# %%
import scoring_methods as score_meth
import scoring_tester as score
import cv2

# %%
score_tester = score.ScoringTester()
score_tester.image_matching_func = score_meth.structural_similarity

# %%
result = score_tester.aggregated_process()
# Out:
# 89/89 comparaisons effectuées
# 89 comparaison effectuées
# 69/69 comparaisons effectuées
# 69 comparaison effectuées
# 574/574 comparaisons effectuées
# 574 comparaison effectuées
# 334/334 comparaisons effectuées
# 334 comparaison effectuées
# 287/287 comparaisons effectuées
# 287 comparaison effectuées
# 107/107 comparaisons effectuées
# 107 comparaison effectuées
# 114/114 comparaisons effectuées
# 114 comparaison effectuées
# 324/324 comparaisons effectuées
# 324 comparaison effectuées
# 364/364 comparaisons effectuées
# 364 comparaison effectuées
# 601/601 comparaisons effectuées
# 601 comparaison effectuées
# 403/403 comparaisons effectuées
# 403 comparaison effectuées
# 1/1 comparaisons effectuées
# 1 comparaison effectuées
# 1/1 comparaisons effectuées
# 1 comparaison effectuées

# %%
print(result)
# Out:
#                  population      mean    median
# Ligne rouge             0.0  0.000000  0.000000
# Over-exposure         114.0  0.549710  0.559261
# Yellowing               1.0  0.569847  0.569847
# Noise                 334.0  0.628065  0.629113
# Black Line            287.0  0.628856  0.629452
# Color Shifting        364.0  0.641471  0.644015
# JPEG Artefact         601.0  0.677509  0.688781
# Ligne Jaune             1.0  0.690802  0.690802
# Pinking                89.0  0.676987  0.692115
# Tearing               574.0  0.697184  0.702189
# Greening               69.0  0.687350  0.708283
# Blur                  324.0  0.701758  0.711261
# Posterisation         403.0  0.723822  0.732297
# White Line            107.0  0.743576  0.749763

# %%
score_tester.process()
# Out:
# 5500/5500 comparaisons effectuées
# 5500 comparaison effectuées

# %%
score_tester.report()
# Out:
# mean 0.6818042852638855
# median 0.6889239706940562
# standard deviation 0.1285543902773169
