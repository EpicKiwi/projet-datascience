# %%
from scipy.spatial import distance as dist
import scoring_tester as score
import cv2

# %%
def calc_diff_images(img_a, img_b):
    hist_a = cv2.calcHist([img_a], [0, 1, 2], None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
    hist_a = cv2.normalize(hist_a, hist_a).flatten()
    hist_b = cv2.calcHist([img_b], [0, 1, 2], None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
    hist_b = cv2.normalize(hist_b, hist_b).flatten()
    return dist.chebyshev(hist_a, hist_b)

# %%
score_tester = score.ScoringTester()
score_tester.image_matching_func = calc_diff_images
score_tester.process()
# Out:
# 5500/5500 comparaisons effectuées
# 5500 comparaison effectuées

# %%
score_tester.report()
# Out:
# mean 0.17304969
# median 0.08485027
# standard deviation 0.2235936
